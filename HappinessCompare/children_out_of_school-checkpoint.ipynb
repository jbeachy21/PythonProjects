# %%
import pandas as pd

school_datapath = "Datasets/children_out_of_school_primary.csv"
school_datapath_clean = "Clean_Datasets/children_out_of_school_primary.csv"

school_data = pd.read_csv(school_datapath)
school_data
# Out:
#                  country  1970      1971      1972      1973       1974  \
# 0            Afghanistan   NaN       NaN       NaN       NaN  1450000.0
# 1                Albania   NaN       NaN       NaN       NaN        NaN
# 2                Algeria   NaN       NaN       NaN  866000.0   781000.0
# 3                 Angola   NaN       NaN       NaN       NaN        NaN
# 4    Antigua and Barbuda   NaN       NaN       NaN       NaN        NaN
# ..                   ...   ...       ...       ...       ...        ...
# 183            Venezuela   NaN  488000.0  484000.0  493000.0   530000.0
# 184              Vietnam   NaN       NaN       NaN       NaN        NaN
# 185                Yemen   NaN       NaN       NaN       NaN        NaN
# 186               Zambia   NaN       NaN  208000.0       NaN        NaN
# 187             Zimbabwe   NaN       NaN       NaN       NaN        NaN
#
#          1975      1976      1977      1978  ...      2011      2012  \
# ...

# %%
school_data_years = school_data[['country', '2015', '2016','2017','2018','2019']]

school_data_columns = school_data_years.rename(columns={'country':'Country'})

school_data_clean = school_data_columns.dropna()
school_data_clean.reset_index()
school_data_clean = school_data_clean[['Country', '2015','2016','2017','2018','2019']]
school_data_clean
# Out:
#                 Country      2015      2016      2017      2018      2019
# 1               Albania    3930.0    3990.0    3630.0    4090.0    3360.0
# 2               Algeria   23200.0   26200.0   19700.0   14200.0   16400.0
# 6               Armenia   10600.0   11800.0   12400.0   11400.0   14900.0
# 9            Azerbaijan    5980.0    4340.0   12200.0   24800.0   55700.0
# 11              Bahrain    1410.0    1350.0     585.0    1190.0    2770.0
# 13             Barbados     905.0     418.0     719.0     328.0     212.0
# 16               Belize     190.0     240.0     148.0     302.0     221.0
# 22               Brunei     260.0      59.0     145.0     295.0     225.0
# 24         Burkina Faso  917000.0  761000.0  747000.0  689000.0  748000.0
# 26             Cambodia   82600.0  134000.0  180000.0  186000.0  190000.0
# 31                 Chad  512000.0  675000.0  840000.0  694000.0  724000.0
# 38           Costa Rica    8010.0    6190.0   13800.0     509.0     555.0
# ...

# %%
school_data_clean.to_csv(school_datapath_clean)
